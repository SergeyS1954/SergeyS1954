# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeyS1954/SergeyS1954/blob/main/Expon_test_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
lam = 1.0
x = np.arange (0.1, 4.0, 0.01)
y1 = stats.expon.cdf(x,0, 1/lam)
y2 = stats.expon.cdf(x, 0, 1/(lam*2))
y3 = stats.expon.cdf(x, 0, 1/(lam*3))
plt.plot(x,y1, label = r" $\lambda_1 = 1$")
plt.plot(x,y2, linestyle = ':', label = r" $\lambda_2 = 2$")
plt.plot(x,y3, linestyle = ':', label = r" $\lambda_3 = 3$")
plt.legend()
plt.title('Функция распределения экспоненциально распределенной случайной величины')
plt.show()
#plt.savefig('app3_expon_1.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
lam = 1.0
y1 = stats.expon.pdf(x,0, 1/lam)
y2 = stats.expon.pdf(x, 0, 1/(lam*2))
y3 = stats.expon.pdf(x, 0, 1/(lam*3))
plt.plot(x,y1, label = r" $\lambda_1 = 1$")
plt.plot(x,y2, linestyle = ':', label = r" $\lambda_2 = 2$")
plt.plot(x,y3, linestyle = ':', label = r" $\lambda_3 = 3$")
plt.legend()
plt.title('Плотность распределения экспоненциально распределенной случайной величины')
plt.show()
#plt.savefig('app3_expon_1.jpg')
